# %% [markdown]
# <a href="https://colab.research.google.com/github/JosemarBrito/Desafio_de_Projeto/blob/main/Aula1_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python para Analise de Dados

# %%
#importando a biblioteca Pandas
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/pandas/Cusro_Python_Pandas_Digital_Innovation-master/datasets/Gapminder.csv', error_bad_lines=False, sep=';')

# %%
#Visualizando as 5 primeiras linhas
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df = df.rename(columns={'country':'Pais','continent':'Continente','year':'Ano','lifeExp':'Exp.Vida','pop':'População','gdpPercap':'PIB'})

# %%
df.head(10)
# Out:
#           Pais Continente   Ano  Exp.Vida  População         PIB
# 0  Afghanistan       Asia  1952    28.801    8425333  779.445314
# 1  Afghanistan       Asia  1957    30.332    9240934  820.853030
# 2  Afghanistan       Asia  1962    31.997   10267083  853.100710
# 3  Afghanistan       Asia  1967    34.020   11537966  836.197138
# 4  Afghanistan       Asia  1972    36.088   13079460  739.981106
# 5  Afghanistan       Asia  1977    38.438   14880372  786.113360
# 6  Afghanistan       Asia  1982    39.854   12881816  978.011439
# 7  Afghanistan       Asia  1987    40.822   13867957  852.395945
# 8  Afghanistan       Asia  1992    41.674   16317921  649.341395
# 9  Afghanistan       Asia  1997    41.763   22227415  635.341351

# %%
#total de linhas e colunas
df.shape
# Out:
# (3312, 6)

# %%
# exibir colunas
df.columns
# Out:
# Index(['Pais', 'Continente', 'Ano', 'Exp.Vida', 'População', 'PIB'], dtype='object')

# %%
df.dtypes
# Out:
# Pais           object
# Continente     object
# Ano             int64
# Exp.Vida      float64
# População       int64
# PIB           float64
# dtype: object

# %%
df.tail()
# Out:
#           Pais Continente   Ano  Exp.Vida  População         PIB
# 3307  Zimbabwe     Africa  1987    62.351    9216418  706.157306
# 3308  Zimbabwe     Africa  1992    60.377   10704340  693.420786
# 3309  Zimbabwe     Africa  1997    46.809   11404948  792.449960
# 3310  Zimbabwe     Africa  2002    39.989   11926563  672.038623
# 3311  Zimbabwe     Africa  2007    43.487   12311143  469.709298

# %%
df.describe()
# Out:
#                Ano     Exp.Vida     População            PIB
# count  3312.000000  3312.000000  3.312000e+03    3312.000000
# mean   1980.301630    65.246871  3.161489e+07   11317.115805
# std      16.927294    11.768412  1.041193e+08   11369.142739
# min    1950.000000    23.599000  5.941200e+04     241.165876
# 25%    1967.000000    58.337500  2.678572e+06    2514.625266
# 50%    1982.000000    69.610000  7.557218e+06    7838.505123
# 75%    1996.000000    73.657750  1.958522e+07   17357.879170
# max    2007.000000    82.670000  1.318683e+09  113523.132900

# %%
df['Continente'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', nan, 'FSU', 'Oceania'],
#       dtype=object)

# %%
america = df.loc[df['Continente'] == 'Americas']
america.head(20)
# Out:
#           Pais Continente   Ano  Exp.Vida  População           PIB
# 48   Argentina   Americas  1952    62.485   17876956   5911.315053
# 49   Argentina   Americas  1957    64.399   19610538   6856.856212
# 50   Argentina   Americas  1962    65.142   21283783   7133.166023
# 51   Argentina   Americas  1967    65.634   22934225   8052.953021
# 52   Argentina   Americas  1972    67.065   24779799   9443.038526
# 53   Argentina   Americas  1977    68.481   26983828  10079.026740
# 54   Argentina   Americas  1982    69.942   29341374   8997.897412
# 55   Argentina   Americas  1987    70.774   31620918   9139.671389
# 56   Argentina   Americas  1992    71.868   33958947   9308.418710
# 57   Argentina   Americas  1997    73.275   36203463  10967.281950
# 58   Argentina   Americas  2002    74.340   38331121   8797.640716
# 59   Argentina   Americas  2007    75.320   40301927  12779.379640
# 339    Bolivia   Americas  1952    40.414    2883315   2677.326347
# ...

# %%
america['Continente'].unique()
# Out:
# array(['Americas'], dtype=object)

# %%
df.groupby('Continente')['Pais'].nunique()
# Out:
# Continente
# Africa      51
# Americas    25
# Asia        41
# Europe      35
# FSU          6
# Oceania      3
# Name: Pais, dtype: int64

# %%
df.groupby('Ano')['Exp.Vida'].mean()
# Out:
# Ano
# 1950    62.002568
# 1951    65.904167
# 1952    49.206867
# 1953    66.674563
# 1954    67.459817
# 1955    67.806757
# 1956    67.950637
# 1957    51.614590
# 1958    68.815936
# 1959    68.226579
# 1960    68.470837
# 1961    68.862480
# 1962    54.035234
# 1963    69.595735
# 1964    70.063105
# 1965    70.259881
# 1966    70.447526
# 1967    56.263629
# 1968    70.689081
# 1969    70.653896
# 1970    70.961141
# 1971    71.103976
# 1972    58.474481
# 1973    71.500338
# 1974    71.778504
# 1975    71.939218
# 1976    72.158050
# 1977    60.429090
# 1978    72.717567
# 1979    73.018717
# 1980    73.064524
# 1981    73.337399
# 1982    62.365871
# 1983    73.787778
# 1984    74.100741
# 1985    74.112222
# 1986    74.452222
# 1987    63.984860
# 1988    74.760000
# 1989    74.924444
# 1990    74.283438
# 1991    74.374848
# 1992    65.008443
# 1993    74.324545
# 1994    74.456667
# 1995    74.552727
# 1996    75.029394
# 1997    65.873799
# 1998    75.569697
# ...

# %%
df['PIB'].mean()
# Out:
# 11317.115804696648

# %%
df['PIB'].sum()
# Out:
# 37482287.5451553
